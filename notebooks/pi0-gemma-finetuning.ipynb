# %% [markdown]
# Run this notebook in docker container "huggingface/lerobot-gpu" (https://hub.docker.com/r/huggingface/lerobot-gpu)

# %%
# !uv pip install --upgrade transformers
# Out:
# Resolved 18 packages in 10.33s
# Prepared 2 packages in 397ms
# Uninstalled 2 packages in 211ms
# Installed 2 packages in 20ms
#  - fsspec==2025.3.0
#  + fsspec==2025.7.0
#  - transformers==4.51.3
#  + transformers==4.55.2

# %%
# !hf auth login --add-to-git-credential --token <hf_token>
# Out:
# Token is valid (permission: fineGrained).
# The token `colab-hf-token` has been saved to /home/user_lerobot/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /home/user_lerobot/.cache/huggingface/token
# Login successful.
# The current active token is: `colab-hf-token`

# %%
# !wandb login <wandb_token>
# Out:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/user_lerobot/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
# !accelerate launch src/lerobot/scripts/train.py \
  --policy.type=pi0 \
  --dataset.repo_id=eliasab16/insert_wire_tip_5 \
  --batch_size=32 \
  --steps=80000 \
  --save_freq=10000 \
  --output_dir=outputs/train/pi0_gemma_batch64_aug19 \
  --job_name=pi0_gemma_batch64_aug19 \
  --policy.device=cuda \
  --policy.repo_id=eliasab16/pi0_gemma_batch64_aug19 \
  --wandb.enable=true
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# INFO 2025-08-19 08:16:58 ts/train.py:111 {'batch_size': 32,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
# ...
